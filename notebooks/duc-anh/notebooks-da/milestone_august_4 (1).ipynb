# %% [markdown]
# # Milestone August 4: Final Validation
# Final validation of the schema before submission to the FinalFlow integration layer.

# %%
import pandas as pd
import os

print("=== MILESTONE AUGUST 4: FINALFLOW SCHEMA VALIDATION ===")

# Dùng chính xác đường dẫn tuyệt đối mà Terminal vừa báo thành công
integration_path = r"E:\download\rice hack (2)\RiceHack\RiceHack\notebooks\duc-anh\data_clean\finalflow_business_integration.csv"

if os.path.exists(integration_path):
    df_final = pd.read_csv(integration_path)
    print("✅ Final Integration File Loaded Successfully.")
    display(df_final.head())
    
    print("\nValidating final schema rules (reasoning attached):")
    display(df_final[['zone_id', 'placement_class', 'reason']].head())
else:
    print(f"⚠️ WARNING: Không tìm thấy file tại {integration_path}.")
# Out:
# === MILESTONE AUGUST 4: FINALFLOW SCHEMA VALIDATION ===
# ✅ Final Integration File Loaded Successfully.
#     zone_id         zone_name   latitude  longitude  \
# 0  ZONE_001  MetLife Sector 1  40.815090 -74.073428
# 1  ZONE_002  MetLife Sector 2  40.813185 -74.075555
# 2  ZONE_003  MetLife Sector 3  40.815543 -74.076431
# 3  ZONE_004  MetLife Sector 4  40.818169 -74.072565
# 4  ZONE_005  MetLife Sector 5  40.812898 -74.071307
#
#    business_opportunity_score  mobility_risk_score placement_class  \
# 0                       53.39                37.29      Controlled
# 1                       37.77                19.08      Controlled
# 2                       29.59                83.98         Avoided
# 3                       47.01                80.19         Avoided
# 4                       95.43                30.64     Recommended
#
#   data_confidence                               reason
# 0            High     Requires strict queue management
# ...
