# %% [markdown]
# # Milestone August 1: Prepare & Visualize
# Loading the clean, aggregated datasets generated for Power BI Dashboard consumption.
#
# ## Power BI Dashboard Specifications (Phương Anh)
# - **Page 1 (Business Overview):** Key KPI Cards (Total Visits, Spend, Trans Count), Top Performing Brands, and Category Breakdown.
# - **Page 2 (Location Opportunity Map):** MetLife Stadium Buffer Zone, POI Density Clusters, and Heat Microclimate Indicators.

# %%
import pandas as pd
import os

print("=== MILESTONE AUGUST 1: REAL FEATURE PREVIEW ===")
clean_dir = '../data_clean/'
files_to_preview = ['daily_business_trends.csv', 'brand_spending_summary.csv', 'visits_by_brand_category.csv']

for file in files_to_preview:
    filepath = os.path.join(clean_dir, file)
    if os.path.exists(filepath):
        print(f"\n Successfully loaded real data: {file}")
        df_preview = pd.read_csv(filepath)
        display(df_preview.head())
    else:
        print(f"WARNING: {file} not found. Ensure 'build_features.py' was executed.")
# Out:
# === MILESTONE AUGUST 1: REAL FEATURE PREVIEW ===
#
#  Successfully loaded real data: daily_business_trends.csv
#    TRANS_DATE   TOTAL_SPEND   TRANS_COUNT
# 0  2020-01-01  1.328500e+08  2.617116e+06
# 1  2020-01-02  1.583767e+08  3.133938e+06
# 2  2020-01-03  1.786495e+08  3.435582e+06
# 3  2020-01-04  1.656777e+08  3.334514e+06
# 4  2020-01-05  1.435819e+08  2.973629e+06
#  Successfully loaded real data: brand_spending_summary.csv
#    BRAND_ID  TOTAL_REVENUE  TOTAL_TRANS  AVG_SPEND_PER_TRANS
# 0     10001   3.409074e+07  178925.2803               190.53
# 1     10002   5.955022e+07  671300.0277                88.71
# 2     10003   2.047599e+07  213420.3997                95.94
# 3     10005   7.874799e+04    2942.0908                26.77
# 4     10006   1.524942e+06   16920.5248                90.12
#  Successfully loaded real data: visits_by_brand_category.csv
#                               BRAND  TOTAL_VISITS
# 0                    1-800 Got Junk        399851
# ...
