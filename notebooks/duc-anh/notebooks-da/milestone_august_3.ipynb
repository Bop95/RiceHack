# %% [markdown]
# # Milestone August 3: Score & Recommend
# Reviewing the Opportunity-Risk scenarios generated by `generate_scenarios.py`.

# %%
import pandas as pd
import os

print("=== MILESTONE AUGUST 3: SCENARIO MATRIX REVIEW ===")
scenario_path = '../data_clean/vendor_zone_scenarios.csv'

if os.path.exists(scenario_path):
    df_scenarios = pd.read_csv(scenario_path)
    print(f"Loaded {len(df_scenarios)} scenario records.")
    display(df_scenarios.head())
    
    print("\nDistribution of Real Placement Classes:")
    print(df_scenarios['placement_class'].value_counts())
else:
    print(f" WARNING: {scenario_path} not found. Run 'generate_scenarios.py' first.")
# Out:
# === MILESTONE AUGUST 3: SCENARIO MATRIX REVIEW ===
# Loaded 50 scenario records.
#     zone_id         zone_name   latitude  longitude  \
# 0  ZONE_001  MetLife Sector 1  40.815090 -74.073428
# 1  ZONE_002  MetLife Sector 2  40.813185 -74.075555
# 2  ZONE_003  MetLife Sector 3  40.815543 -74.076431
# 3  ZONE_004  MetLife Sector 4  40.818169 -74.072565
# 4  ZONE_005  MetLife Sector 5  40.812898 -74.071307
#
#    business_opportunity_score  mobility_risk_score placement_class
# 0                       53.39                37.29      Controlled
# 1                       37.77                19.08      Controlled
# 2                       29.59                83.98         Avoided
# 3                       47.01                80.19         Avoided
# 4                       95.43                30.64     Recommended
# Distribution of Real Placement Classes:
# placement_class
# Controlled     32
# Avoided        11
# Recommended     7
# Name: count, dtype: int64
